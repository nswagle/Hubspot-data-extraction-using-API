# %%
import requests
import pandas as pd
import json

url = "https://api.hubapi.com/crm/v3/objects/contacts"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response = requests.request("GET", url, headers=headers)


js2 = json.loads(response.text)

allResults = list()
counter = 0

while('paging' in js2):
    allResults.extend(js2['results'])
    url = js2['paging']['next']['link']
    print(url)
    response = requests.request("GET", url, headers=headers)
    js2 = json.loads(response.text)
    counter = counter + 1
    
out_file = open("contactsNew.json", "w")
  
json.dump(allResults, out_file, indent = 6)
  
out_file.close()
# Out:
# https://api.hubapi.com/crm/v3/objects/contacts?after=5064
# https://api.hubapi.com/crm/v3/objects/contacts?after=5074
# https://api.hubapi.com/crm/v3/objects/contacts?after=5084
# https://api.hubapi.com/crm/v3/objects/contacts?after=5094
# https://api.hubapi.com/crm/v3/objects/contacts?after=5154
# https://api.hubapi.com/crm/v3/objects/contacts?after=5302
# https://api.hubapi.com/crm/v3/objects/contacts?after=5456
# https://api.hubapi.com/crm/v3/objects/contacts?after=5466
# https://api.hubapi.com/crm/v3/objects/contacts?after=5476
# https://api.hubapi.com/crm/v3/objects/contacts?after=5486
# https://api.hubapi.com/crm/v3/objects/contacts?after=5496
# https://api.hubapi.com/crm/v3/objects/contacts?after=5555
# https://api.hubapi.com/crm/v3/objects/contacts?after=5565
# https://api.hubapi.com/crm/v3/objects/contacts?after=5575
# https://api.hubapi.com/crm/v3/objects/contacts?after=5585
# https://api.hubapi.com/crm/v3/objects/contacts?after=5595
# ...

# %%
import pandas as pd
import json
with open('contactsNew.json','r') as f:
    data = json.loads(f.read())
df = pd.json_normalize(data)
df.to_csv('contacts_excel.csv')

# %%
url2 = "https://api.hubapi.com/crm/v4/objects/companies"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response2 = requests.request("GET", url2, headers=headers)


js3 = json.loads(response2.text)

allResults2 = list()
counter = 0

while('paging' in js3):
    allResults2.extend(js3['results'])
    url2 = js3['paging']['next']['link']
    print(url2)
    response2 = requests.request("GET", url2, headers=headers)
    js3 = json.loads(response2.text)
    counter = counter + 1
    
out_file2 = open("companiesdata.json", "w")
  
json.dump(allResults2, out_file2, indent = 6)
  
out_file2.close()
# Out:
# https://api.hubapi.com/crm/v3/objects/companies?properties=lifecyclestage%22&after=4995085304
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085507&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085518&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085528&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085538&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085548&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085558&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085760&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085771&properties=lifecyclestage%22
# https://api.hubapi.com/crm/v3/objects/companies?after=4995085781&properties=lifecyclestage%22
# ...

# %%
with open('companiesdata.json','r') as f:
    data = json.loads(f.read())
df2 = pd.json_normalize(data)
df2.to_excel('updatedcompaniesdata.xlsx')

# %%
df2
# Out:
#               id                 createdAt                 updatedAt  \
# 0     4995085294  2021-11-26T13:14:09.078Z  2022-04-30T19:47:19.166Z
# 1     4995085295  2021-11-26T13:14:09.083Z  2022-09-22T07:44:37.802Z
# 2     4995085296  2021-11-26T13:14:09.084Z  2022-09-01T15:08:03.360Z
# 3     4995085297  2021-11-26T13:14:09.082Z  2022-04-30T19:46:45.776Z
# 4     4995085298  2021-11-26T13:14:09.087Z  2022-09-09T07:00:22.767Z
# ...          ...                       ...                       ...
# 9425  6452671201  2022-10-19T19:02:47.766Z  2022-10-21T07:48:35.941Z
# 9426  6452697336  2022-10-19T18:59:25.467Z  2022-10-21T07:48:36.022Z
# 9427  6458536893  2022-10-21T11:20:28.345Z  2022-10-21T11:39:17.228Z
# 9428  6464796883  2022-10-24T08:23:01.224Z  2022-10-24T08:26:03.399Z
# 9429  6464919770  2022-10-24T08:26:51.084Z  2022-10-24T08:27:09.627Z
#
#       archived     properties.createdate    properties.domain  \
# 0        False  2021-11-26T13:14:09.078Z               atu.de
# ...

# %%
url3 = "https://api.hubapi.com/crm/v4/objects/deals"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response3 = requests.request("GET", url3, headers=headers)


js4 = json.loads(response3.text)

allResults3 = list()
counter = 0

while('paging' in js4):
    allResults3.extend(js4['results'])
    url3 = js4['paging']['next']['link']
    print(url3)
    response3 = requests.request("GET", url3, headers=headers)
    js4 = json.loads(response3.text)
    counter = counter + 1
    
out_file3 = open("dealsdata.json", "w")
  
json.dump(allResults3, out_file3, indent = 6)
  
out_file3.close()
# Out:
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749362
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749564
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749574
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749585
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749595
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749606
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749616
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749819
# https://api.hubapi.com/crm/v4/objects/deals?after=3955749831
# https://api.hubapi.com/crm/v4/objects/deals?after=3955804136
# https://api.hubapi.com/crm/v4/objects/deals?after=3955804147
# https://api.hubapi.com/crm/v4/objects/deals?after=3955804349
# https://api.hubapi.com/crm/v4/objects/deals?after=3955804359
# https://api.hubapi.com/crm/v4/objects/deals?after=3955804369
# https://api.hubapi.com/crm/v4/objects/deals?after=3955804379
# ...

# %%
with open('dealsdata.json','r') as f:
    data = json.loads(f.read())
df3 = pd.json_normalize(data)
df3.to_csv('dealsdata.csv')

# %%
url4 = "https://api.hubapi.com/crm/v4/objects/products"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response4 = requests.request("GET", url4, headers=headers)


js5 = json.loads(response4.text)

allResults4 = list()
counter = 0
while('paging' in js5):
    allResults4.extend(js5['results'])
    url4 = js5['paging']['next']['link']
    print(url4)
    response4 = requests.request("GET", url4, headers=headers)
    js5 = json.loads(response4.text)
    counter = counter + 1
    
out_file4 = open("products_data.json", "w")
  
json.dump(allResults4, out_file4, indent = 6)
  
out_file4.close()

# %%
with open('products_data.json','r') as f:
    data = json.loads(f.read())
df4 = pd.json_normalize(data)
df4.to_csv('products_data.csv')

# %%
url5 = "https://api.hubapi.com/crm/v4/objects/tickets"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response5 = requests.request("GET", url5, headers=headers)


js6 = json.loads(response5.text)

allResults5 = list()
counter = 0
while('paging' in js6):
    allResults5.extend(js6['results'])
    url5 = js6['paging']['next']['link']
    print(url5)
    response5 = requests.request("GET", url5, headers=headers)
    js6 = json.loads(response5.text)
    counter = counter + 1
    
out_file5 = open("tickets_data.json", "w")
  
json.dump(allResults5, out_file5, indent = 6)
  
out_file5.close()

# %%
with open('tickets_data.json','r') as f:
   data = json.loads(f.read())
df5 = pd.json_normalize(data)
df5.to_csv('tickets_data.csv')

# %%
url6 = "https://api.hubapi.com/crm/v4/objects/quotes"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response6 = requests.request("GET", url6, headers=headers)


js7 = json.loads(response6.text)
allResults6 = list()
counter = 0
while('paging' in js6):
    allResults5.extend(js7['results'])
    url5 = js7['paging']['next']['link']
    print(url6)
    response6 = requests.request("GET", url6, headers=headers)
    js6 = json.loads(response6.text)
    counter = counter + 1
out_file6 = open("quotesdata.json", "w")
  
json.dump(allResults6, out_file6, indent = 6)
  
out_file6.close()

# %%
with open('quotesdata.json','r') as f:
   data = json.loads(f.read())
df6 = pd.json_normalize(data)
df6.to_csv('quotesdata.csv')

# %%
url7 = "https://api.hubapi.com/crm/v4/objects/calls"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response7 = requests.request("GET", url7, headers=headers)


js8 = json.loads(response7.text)

allResults7 = list()
counter = 0

while('paging' in js8):
    allResults3.extend(js8['results'])
    url7 = js8['paging']['next']['link']
    print(url7)
    response7 = requests.request("GET", url7, headers=headers)
    js8 = json.loads(response7.text)
    counter = counter + 1
    
out_file7 = open("calls_data.json", "w")
  
json.dump(allResults7, out_file7, indent = 6)
  
out_file7.close()
# Out:
# https://api.hubapi.com/crm/v4/objects/calls?after=11869635036
# https://api.hubapi.com/crm/v4/objects/calls?after=11875977936
# https://api.hubapi.com/crm/v4/objects/calls?after=11876977618
# https://api.hubapi.com/crm/v4/objects/calls?after=11884879565
# https://api.hubapi.com/crm/v4/objects/calls?after=11894296521
# https://api.hubapi.com/crm/v4/objects/calls?after=11896129227
# https://api.hubapi.com/crm/v4/objects/calls?after=11901718522
# https://api.hubapi.com/crm/v4/objects/calls?after=11902484439
# https://api.hubapi.com/crm/v4/objects/calls?after=11902515131
# https://api.hubapi.com/crm/v4/objects/calls?after=11906469104
# https://api.hubapi.com/crm/v4/objects/calls?after=11907790790
# https://api.hubapi.com/crm/v4/objects/calls?after=11910484464
# https://api.hubapi.com/crm/v4/objects/calls?after=11910817506
# https://api.hubapi.com/crm/v4/objects/calls?after=11911039702
# https://api.hubapi.com/crm/v4/objects/calls?after=11911225824
# ...

# %%
with open('calls_data.json','r') as f:
   data = json.loads(f.read())
df7 = pd.json_normalize(data)
df7.to_csv('calls_data.csv')

# %%
url8 = "https://api.hubapi.com/crm/v4/objects/emails"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response8 = requests.request("GET", url8, headers=headers)


js9 = json.loads(response8.text)

allResults8 = list()
counter = 0

while('paging' in js9):
    allResults8.extend(js9['results'])
    url8 = js9['paging']['next']['link']
    print(url8)
    response8 = requests.request("GET", url8, headers=headers)
    js9 = json.loads(response8.text)
    counter = counter + 1
    
out_file8 = open("emails_data.json", "w")
  
json.dump(allResults8, out_file8, indent = 6)
  
out_file8.close()
# Out:
# https://api.hubapi.com/crm/v4/objects/emails?after=11735497673
# https://api.hubapi.com/crm/v4/objects/emails?after=11736337114
# https://api.hubapi.com/crm/v4/objects/emails?after=11737870328
# https://api.hubapi.com/crm/v4/objects/emails?after=11850790630
# https://api.hubapi.com/crm/v4/objects/emails?after=11872275394
# https://api.hubapi.com/crm/v4/objects/emails?after=11885914322
# https://api.hubapi.com/crm/v4/objects/emails?after=11898106868
# https://api.hubapi.com/crm/v4/objects/emails?after=11906612171
# https://api.hubapi.com/crm/v4/objects/emails?after=11908053224
# https://api.hubapi.com/crm/v4/objects/emails?after=11920391625
# https://api.hubapi.com/crm/v4/objects/emails?after=11926765278
# https://api.hubapi.com/crm/v4/objects/emails?after=11930339546
# https://api.hubapi.com/crm/v4/objects/emails?after=11935539173
# https://api.hubapi.com/crm/v4/objects/emails?after=11938643940
# https://api.hubapi.com/crm/v4/objects/emails?after=11940589786
# ...

# %%
with open('emails_data.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_csv('emails_data.csv')

# %%
url9= "https://api.hubapi.com/crm/v4/objects/meetings"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response9= requests.request("GET", url9, headers=headers)


js10= json.loads(response9.text)

allResults9 = list()
counter = 0

while('paging' in js10):
    allResults9.extend(js10['results'])
    url9 = js10['paging']['next']['link']
    print(url9)
    response9 = requests.request("GET", url9, headers=headers)
    js10 = json.loads(response9.text)
    counter = counter + 1
    
out_file9 = open("Meetingdata.json", "w")
  
json.dump(allResults9, out_file9, indent = 6)
  
out_file9.close()
# Out:
# https://api.hubapi.com/crm/v4/objects/meetings?after=11762690790
# https://api.hubapi.com/crm/v4/objects/meetings?after=11869008366
# https://api.hubapi.com/crm/v4/objects/meetings?after=11903846624
# https://api.hubapi.com/crm/v4/objects/meetings?after=11941817316
# https://api.hubapi.com/crm/v4/objects/meetings?after=11963080636
# https://api.hubapi.com/crm/v4/objects/meetings?after=11998500082
# https://api.hubapi.com/crm/v4/objects/meetings?after=12035570624
# https://api.hubapi.com/crm/v4/objects/meetings?after=12062787555
# https://api.hubapi.com/crm/v4/objects/meetings?after=12093928925
# https://api.hubapi.com/crm/v4/objects/meetings?after=12166024174
# https://api.hubapi.com/crm/v4/objects/meetings?after=12202477039
# https://api.hubapi.com/crm/v4/objects/meetings?after=12239112661
# https://api.hubapi.com/crm/v4/objects/meetings?after=12258051779
# https://api.hubapi.com/crm/v4/objects/meetings?after=12314339543
# ...

# %%
with open('Meetingdata.json','r') as f:
   data = json.loads(f.read())
df10 = pd.json_normalize(data)
df10.to_csv('Meetingdata.csv')

# %%
url10= "https://api.hubapi.com/crm/v4/objects/notes"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response10= requests.request("GET", url10, headers=headers)


js11= json.loads(response10.text)

allResults10 = list()
counter = 0

while('paging' in js11):
    allResults10.extend(js11['results'])
    url10 = js11['paging']['next']['link']
    print(url10)
    response10 = requests.request("GET", url10, headers=headers)
    js11 = json.loads(response10.text)
    counter = counter + 1
    
out_file10 = open("notes_data.json", "w")
  
json.dump(allResults10, out_file10, indent = 6)
  
out_file10.close()
# Out:
# https://api.hubapi.com/crm/v4/objects/notes?after=11763084013
# https://api.hubapi.com/crm/v4/objects/notes?after=11763146948
# https://api.hubapi.com/crm/v4/objects/notes?after=11763151553
# https://api.hubapi.com/crm/v4/objects/notes?after=11763203030
# https://api.hubapi.com/crm/v4/objects/notes?after=11763210200
# https://api.hubapi.com/crm/v4/objects/notes?after=11767520748
# https://api.hubapi.com/crm/v4/objects/notes?after=11767539181
# https://api.hubapi.com/crm/v4/objects/notes?after=11767541697
# https://api.hubapi.com/crm/v4/objects/notes?after=11767583420
# https://api.hubapi.com/crm/v4/objects/notes?after=11767585212
# https://api.hubapi.com/crm/v4/objects/notes?after=11767677689
# https://api.hubapi.com/crm/v4/objects/notes?after=11767726291
# https://api.hubapi.com/crm/v4/objects/notes?after=11767776977
# https://api.hubapi.com/crm/v4/objects/notes?after=11767798979
# https://api.hubapi.com/crm/v4/objects/notes?after=11767803068
# ...

# %%
with open('notes_data.json','r') as f:
   data = json.loads(f.read())
df11 = pd.json_normalize(data)
df11.to_csv('notes_data.csv')

# %%
url11= "https://api.hubapi.com/crm/v4/objects/postal_mail"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response11= requests.request("GET", url11, headers=headers)


js12= json.loads(response11.text)

allResults11 = list()
counter = 0

while('paging' in js12):
    allResults11.extend(js12['results'])
    url11 = js12['paging']['next']['link']
    print(url11)
    response11 = requests.request("GET", url11, headers=headers)
    js12 = json.loads(response11.text)
    counter = counter + 1
    
out_file11 = open("postal_mail_data.json", "w")
  
json.dump(allResults11, out_file11, indent = 6)
  
out_file11.close()

# %%
with open('postal_mail_data.json','r') as f:
   data = json.loads(f.read())
df12 = pd.json_normalize(data)
df12.to_csv('postal_mail_data.csv')

# %%
import schedule 
import time
def job():
    url12= "https://api.hubapi.com/crm/v4/objects/tasks"
    YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
    headers = {
      'content-type': 'application/json',
      'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
    }

    response12= requests.request("GET", url12, headers=headers)


    js13= json.loads(response12.text)

    allResults12 = list()
    counter = 0

    while('paging' in js13):
        allResults12.extend(js13['results'])
        url12 = js13['paging']['next']['link']
        print(url12)
        response12 = requests.request("GET", url12, headers=headers)
        js13 = json.loads(response12.text)
        counter = counter + 1
    
    out_file12 = open("tasks_data.json", "w")
  
    json.dump(allResults12, out_file12, indent = 6)
  
    out_file12.close()
schedule.every(500).seconds.do(job)
# Out:
# Every 500 seconds do job() (last run: [never], next run: 2023-01-19 10:57:49)

# %%
with open('tasks_data.json','r') as f:
   data = json.loads(f.read())
df13 = pd.json_normalize(data)
df13.to_excel('tasks_data.xlsx')

# %%
import hubspot
from pprint import pprint
from hubspot.crm.owners import ApiException
url12= "https://api.hubapi.com/crm/v3/owners/{ownerId}"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response12= requests.request("GET", url12, headers=headers)


js13= json.loads(response12.text)

allResults12 = list()
counter = 0

while('paging' in js13):
    allResults12.extend(js13['results'])
    url12 = js13['paging']['next']['link']
    print(url12)
    response12 = requests.request("GET", url12, headers=headers)
    js13 = json.loads(response12.text)
    counter = counter + 1
    
out_file12 = open("owner_data.json", "w")
  
json.dump(allResults12, out_file12, indent = 6)
  
out_file12.close()

# %%
with open('owner_data.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_csv('owner_data.csv')

# %%
import requests
import pandas as pd
import json
url13 = "https://api.hubapi.com/contacts/search/v1/external/lifecyclestages?hapikey=demo&fromTimestamp=1577918291&toTimestamp=1643668691"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response13 = requests.request("GET", url13, headers=headers)


js14 = json.loads(response13.text)

js14
# Out:
# [{'lifecycleStage': 'hs_lifecyclestage_lead_date', 'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_opportunity_date', 'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_marketingqualifiedlead_date',
#   'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_salesqualifiedlead_date', 'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_evangelist_date', 'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_customer_date', 'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_subscriber_date', 'count': 0},
#  {'lifecycleStage': 'hs_lifecyclestage_other_date', 'count': 0}]

# %%
with open('salescyclestage.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_excel('salescyclestage.xlsx')

# %%
import requests
import pandas as pd
import json
url13 = "https://api.hubapi.com/contacts/v1/lists/all/contacts/all?"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response13 = requests.request("GET", url13, headers=headers)


js14 = json.loads(response13.text)

with open("sample.json", "w") as outfile:
    json.dump(js14, outfile)

js14

# %%
with open('sample.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_excel('contacts_all.e')

# %%
import requests
import pandas as pd
import json
url10= f"https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization':f'Bearer {YOUR_ACCESS_TOKEN}' #'Bearer %s' % YOUR_ACCESS_TOKEN  
}

response10= requests.request("GET", url10, headers=headers)


js11= json.loads(response10.text)

allResults10 = list()
counter = 0

while('paging' in js11):
    allResults10.extend(js11['results'])
    url10 = js11['paging']['next']['link']
    print(url10)
    response10 = requests.request("GET", url10)
    js11 = json.loads(response10.text)
    counter = counter + 1
    
out_file10 = open("lifecycle_data.json", "w")
  
json.dump(allResults10, out_file10, indent = 6)
  
out_file10.close()
print(response10.text)
# Out:
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085305
# {"status":"error","message":"Authentication credentials not found. This API supports both API Key and OAuth 2.0 authentication and you can find more details at https://developers.hubspot.com/docs/methods/auth/oauth-overview","correlationId":"990f1727-2be1-4328-90a8-1899e845e13e","category":"INVALID_AUTHENTICATION"}

# %%
#pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32
api_key = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
endpoint = "https://api.hubapi.com/contacts/v1/lifecyclestages/?hapikey=" + api_key
response = requests.get(endpoint)
data = json.loads(response.text)
contact_id = "25217402"
lifecycle_stage = data[contact_id]["lifecycleStage"]["label"]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [13], line 5
#       3 endpoint = "https://api.hubapi.com/contacts/v1/lifecyclestages/?hapikey=" + api_key
#       4 response = requests.get(endpoint)
# ----> 5 data = json.loads(response.text)
#       6 contact_id = "25217402"
#       7 lifecycle_stage = data[contact_id]["lifecycleStage"]["label"]
#
# File ~\miniconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
with open('lifecycle_data.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_excel('contacts_all.xlsx')

# %%
import requests
import pandas as pd
import json
url10= f" https://api.hubapi.com/crm/v4/objects/deals?archived=false?fromTimestamp=1678635596&toTimestamp=1678808787"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization':f'Bearer {YOUR_ACCESS_TOKEN}' #'Bearer %s' % YOUR_ACCESS_TOKEN  
}

response10= requests.request("GET", url10, headers=headers)


js11= json.loads(response10.text)

allResults10 = list()
counter = 0

while('paging' in js11):
    allResults10.extend(js11['results'])
    url10 = js11['paging']['next']['link']
    print(url10)
    response10 = requests.request("GET", url10)
    js11 = json.loads(response10.text)
    counter = counter + 1
    
out_file10 = open("lifecycle_data.json", "w")
  
json.dump(allResults10, out_file10, indent = 6)
  
out_file10.close()
print(response10.text)
# Out:
# C:\Users\NikhilWagle\miniconda3\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085305
# {"status":"error","message":"Authentication credentials not found. This API supports both API Key and OAuth 2.0 authentication and you can find more details at https://developers.hubspot.com/docs/methods/auth/oauth-overview","correlationId":"d7b54abe-98e7-40c0-89f3-44744756fccc","category":"INVALID_AUTHENTICATION"}

# %%
with open('lifecycle_data.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_excel('deals2.xlsx')

# %%
import requests
import pandas as pd
import json

url2 = "https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage"
YOUR_ACCESS_TOKEN = "pat-eu1-1c90cffe-64af-44f1-b0e3-afe6a2041f32"
headers = {
  'content-type': 'application/json',
  'authorization': 'Bearer %s' % YOUR_ACCESS_TOKEN
}

response2 = requests.request("GET", url2, headers=headers)


js3 = json.loads(response2.text)

allResults2 = list()
counter = 0

while('paging' in js3):
    allResults2.extend(js3['results'])
    url2 = js3['paging']['next']['link']
    print(url2)
    response2 = requests.request("GET", url2, headers=headers)
    js3 = json.loads(response2.text)
    counter = counter + 1
    
out_file2 = open("companiesdata.json", "w")
  
json.dump(allResults2, out_file2, indent = 6)
  
out_file2.close()
# Out:
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085305
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085508
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085520
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085530
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085540
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085550
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085560
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085762
# https://api.hubapi.com/crm/v3/objects/companies?propertiesWithHistory=lifecyclestage&after=4995085773
# ...

# %%
print(response2.text)
# Out:
# {"results":[{"id":"7184078525","properties":{"createdate":"2023-03-15T08:23:09.742Z","domain":"allegion.com","hs_lastmodifieddate":"2023-03-15T08:23:44.771Z","hs_object_id":"7184078525","name":"Allegion plc"},"propertiesWithHistory":{"lifecyclestage":[{"value":"lead","timestamp":"2023-03-15T08:23:09.742Z","sourceType":"COMPANIES","sourceId":"FetchAssociatedCompanyIdStep"}]},"createdAt":"2023-03-15T08:23:09.742Z","updatedAt":"2023-03-15T08:23:44.771Z","archived":false},{"id":"7186472124","properties":{"createdate":"2023-03-15T08:19:53.854Z","domain":"axabikesecurity.com","hs_lastmodifieddate":"2023-03-15T08:23:13.395Z","hs_object_id":"7186472124","name":"AXA Stenman Deutschland GmbH"},"propertiesWithHistory":{"lifecyclestage":[{"value":"lead","timestamp":"2023-03-15T08:19:53.854Z","sourceType":"CRM_UI","sourceId":"userId:48913646","updatedByUserId":48913646}]},"createdAt":"2023-03-15T08:19:53.854Z","updatedAt":"2023-03-15T08:23:13.395Z","archived":false}]}

# %%
with open('companiesdata.json','r') as f:
   data = json.loads(f.read())
df8 = pd.json_normalize(data)
df8.to_csv('Lifecyclestages.csv')

# %%
import pandas as pd
import json
import chardet

with open('zendesk_2023.json', 'rb') as f:
   result = chardet.detect(f.read())
   
with open('zendesk_2023.json', 'r', encoding=result['encoding']) as f:
   data = json.loads(f.read())

df8 = pd.json_normalize(data)
df8.to_excel('zendeskdata2023.xlsx')
